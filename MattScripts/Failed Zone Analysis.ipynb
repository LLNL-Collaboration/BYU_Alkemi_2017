# %% [markdown]
# # Analysis of Failed Zones

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Here you can input the desired run and it will give us the data for all cycles of the failed zone in that run.

# %%
def my_read_file(num):
    filename = "fail_data_" + str(num) + ".csv"
    data = pd.read_csv(filename)
    return data
    
num = input("Input Run: ",)
my_read_file(num).head()
# Out:
# Input Run: 7
#      volume  aspectRatio  conditionNumber  distortion  jacobian  largestAngle  \
# 0  0.055523     3.079794         1.723410    0.984829  0.005004     92.136948
# 1  0.052371     2.864706         1.619831    0.989820  0.004737     92.125359
# 2  0.050110     2.706033         1.558324    0.982683  0.004494     92.306694
# 3  0.049929     2.692417         1.553176    0.981962  0.004474     92.295830
# 4  0.049918     2.691601         1.552870    0.981916  0.004473     92.295143
#
#        oddy  scaledJacobian     shape  shapeAndSize     shear  shearAndSize  \
# 0  3.940281        0.999305  0.580245      0.580245  0.999305      0.999305
# 1  3.247707        0.999306  0.617348      0.617348  0.999306      0.999306
# 2  2.856747        0.999000  0.641715      0.641715  0.999000      0.999000
# 3  2.824710        0.998985  0.643842      0.643842  0.998985      0.998985
# 4  2.822808        0.998985  0.643969      0.643969  0.998985      0.998985
#
#        skew  smallestAngle   stretch     taper
# 0  0.006695      88.083153  0.433572  0.029076
# 1  0.008741      87.864853  0.464783  0.028466
# 2  0.012221      87.437340  0.485372  0.031169
# 3  0.012293      87.418877  0.487187  0.031328
# 4  0.012297      87.417732  0.487296  0.031339

# %%
#make a plot for each of the spikes
for i in range(0,10):
    file = "fail_data_" + str(i) + ".csv"
    data = pd.read_csv(file)
    
    x = range(0,data.shape[0])
    y = data["oddy"]
    
    
    colors = ['red','blue','green','orange','purple','yellow',\
             'turquoise','gray','gold','aquamarine']
    plt.plot(x,y,'-o',color=colors[i])
    plt.xlabel("Time")
    plt.ylabel("Oddy")
    plt.xlim([5000,10000])
    plt.ylim([-50000,500000])
    plotname = "Oddy Spike for Run:  " + str(i)
    plt.title(plotname)
    plt.show()

# %% [markdown]
# TO DO LIST:
# - make a loop to run through all the failed zones and extract the magnitude of the oddy spikes
#   as well as when they start and stop
# - figure out how to automate the process of gathering the data for ALL of the failed zones that we
#   have access too.
# - Analyze the group of gathered data for each oddy spike
# - Repeat the process for 'soon-to-fail' zones as well

# %%
#I will set up the analysis for a single zone, and then set up a loop to run through them all

# num = input("Input Run: ",)
num = 7
data = my_read_file(num)

#find the magnitude of the oddy spike
spike_data = {}
spike_data['min'] = min(data['oddy'])
spike_data['max'] = max(data['oddy'])
spike_data['magnitude'] = max(data['oddy']) - min(data['oddy'])

#look at the duration of the oddy spike
#Where exactly does the spike 'begin' the rate of increase is initally very slow, but the rate increases with time.
#consider using the slope to determine when there is a spike
spike_data['duration'] =
# Out:
# {'magnitude': 2538057213.1775651,
#  'max': 2538057216.0,
#  'min': 2.8224349021900004}
